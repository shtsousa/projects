# %% [markdown]
# <a href="https://colab.research.google.com/github/shtsousa/projects/blob/main/Algoritmo_de_Ordena%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random 
def insertion_sort(lista):
  n = len(lista)
  for i in range(1, n):
    key = lista[i]
    j = i - 1
    while j >= 0 and lista[j] > key:
      lista[j+1] = lista[j]
      j = j - 1
  lista[j+1] = key


def selection_sort(lista):  
  n = len(lista)
  for j in range(n-1):
    min_value = j
  for i in range(j, n):
    if lista[i] < lista[min_value]:
      min_value = [i]
  if lista[j] > lista[min_value]:
    aux = lista[j]
    lista[j] = lista[min_value]
    lista[min_value] = aux
    

def bubble_sort(lista):
  n = len(lista)
  for j in range(n-1):
    for i in range(n-1):
      if lista[i] > lista[i+1]:
        lista[i], lista[i+1] = lista[i+1], lista[i] #troca de elemento nas posicoes i e i+1

def merge_sort(lista, inicio= 0, fim = None):
  if fim is None:
    fim = len(lista)
  if (fim - inicio > 1):
    meio = (fim+inicio)//2
    merge_sort(lista,inicio,meio)
    merge_sort(lista,meio,fim)
    merge(inicio,meio,fim)

def merge(lista, inicio, meio, fim):
  listaleft = lista[inicio:meio]
  listaright = lista[meio:fim]
  top_left, top_right = 0, 0
  for k in range(inicio,fim):
    if top_left >= len(top_left):
      lista[k] = listaright[top_right]
      top_right = top_right+1
    if top_right >= len(top_right):
      lista[k] = listaleft[top_left]      
      top_left = top_left+1

    if listaleft[i] < listaright[top_right]:
      lista[k] = listaleft[top_left]      
      top_left = top_left+1
    else:
      lista[k] = listaright[top_right]
      top_right = top_right+1

numbers = random.sample(range(1,1000),100)

already_sorted = [1, 2, 3, 4, 5, 6, 9, 20, 22, 23, 28,
                    32, 34, 39, 40, 42, 76, 87, 99, 112]

inversed = [117, 90, 88, 83, 81, 77, 74, 69, 64, 63, 51,
            50, 49, 42, 41, 34, 32, 29, 28, 22, 16, 8, 6, 5, 3, 1]

repeated = [7, 7, 7, 7, 7, 1, 1, 9, 9, 0, 4, 4, 4, 5, 4, 5, 7, 1,]

if __name__ == "__main__":

#Insert Sort
  lista = already_sorted
print("Insertion Sort\n",lista)
insertion_sort(lista)
print("\nOrder:")
print(lista)
print("\nOrder without repetitions")
print(sorted(set(lista)))

#Selection Sort
lista = already_sorted
print("\n\nSelection Sort\n",lista)
selection_sort(lista)
print("\nOrder:")
print(lista)
print("\nOrder without repetitions")
print(sorted(set(lista)))

#Bubble Sort
lista = inversed
print("\n\nBubble Sort\n",lista)
bubble_sort(lista)
print("\nOrder:")
print(lista)
print("\nOrder without repetitions")
print(sorted(set(lista)))

#Merge Sort
lista = numbers
print("\n\nMerge Sort\n",lista)
bubble_sort(lista)
print("\nOrder:")
print(lista)
print("\nOrder without repetitions")
print(sorted(set(lista)))
