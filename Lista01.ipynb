# %% [markdown]
# <a href="https://colab.research.google.com/github/shtsousa/projects/blob/main/Lista01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''#1)Dados com While
import random  #biblioteca pra numero aleatorio
from random import randint

rept= 'y'
while rept != 'n':

  print('Rolling the Dices\nThe Values are...')
  dado1 = random.randint(1,6)
  dado2 = random.randint(1,6)
  print(dado1,dado2)

  rept = str (input('Roll the dices again?(y/n)'))
  
else:
  print("See you later!") ''' 


'''#2)Exercício fatorial
print('Welcome to FactoProgram!\n')
value = int(input('Insert number: '))  
fatorial = 1  
while (value > 1):  
  fatorial = fatorial * value  
  value = value - 1  
print(f'Value is: {fatorial}.')'''


'''#3)Exercício Fibonacci

print('Hello! Welcome to FibonacciProgram')

fibo = int (input('Insert number: '))

num1 = 1
num2 = 1
numdef = 0

seq = [0,1,1]

for fibo in range(0,2):
  numdef = num1 + num2
  num1 = numdef
  num2 = (numdef - num2)
  seq.append(numdef) #para gerar a sequencia

print (seq,'\n \nGoodbye!')'''

'''4)Exercício nºs pares com for e while

print('Hello! Welcome to "Pair Program"')

num = 200 #declarei 200 pois mostrara os 100 primeiros através dele

value = 0
while value <= num:
     if value % 2 == 0:
         print(value)
     value = value + 1'''


''' number = 200 #declarei 200 pois mostrara os 100 primeiros através dele

lst = []
for n in range(number+0):
    if n%2==0:
        lst.append(n) #para gerar toda a lista

print('',' ',lst, sep='\n')'''

'''#5 Distancia entre valores (tenho dificuldade)'''


#6 Imprimir duração do evento com horas

#importando bibliotecas para fazer um cronometro como base 
#!/usr/bin/python

from datetime import datetime, timedelta
from sys import stdout

print('Welcome to ConvertSeconds')
secs = int(input('\nHow long is the event bro?\n))
time = timedelta(seconds=secs)
print(time)
