# %% [markdown]
# <a href="https://colab.research.google.com/github/shtsousa/projects/blob/main/CalculadoraIMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Abertura do programa
print("Seja bem-vindo ao Programa de Re-educacao alimentar\nLembramos que todos os dados aqui são baseados numa amostra não comprovada podendo varias em seus indices")
nome=input("Insira seu nome: ")

print(f"\nOla {nome}, seja bem vindo ao Programa de Re-educacao alimentar ltda\n")

#Cadastro do cliente e importação de algumas bibliotecas
import os
import re
import pandas
print("Para melhor atendermos, vamos realizar seu cadastro")
import getpass #getpass pra senha
log = input("Login: ")
senha = getpass.getpass(prompt='Senha: ', stream=None)
email = input("E-mail: ")
print("Cadastro realizado com sucesso !")

#Inserção de dados para calcular
print("Agora que nos conhecemos melhor, nos diga um pouco sobre você")
 
alt = float(input("Qual sua altura(M): "))
idade = int(input("Qual sua idade: "))
peso = float(input("Qual seu peso(Kg): "))
sexo = str(input("Digita o seu sexo (M/F): "))
imc = peso / (alt ** 2)


if sexo == "M":
    if idade == 1:
        if imc >= 19.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 18.2:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 14.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 2:
        if imc >= 18.7:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.4:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 14:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 3:
        if imc >= 18.2:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.4:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 4:
        if imc >= 18:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 16.7:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.2:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 5:
        if imc >= 18.1:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 16.7:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 6:
        if imc >= 18.4:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 16.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.2:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 7:
        if imc >= 18.7:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.2:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.3:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if id == 8:
        if imc >= 19.4:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.5:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 9:
        if imc >= 20.1:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 18:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.6:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 10:
        if imc >= 28.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 25:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 17.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 11:
        if imc >= 22:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 19.3:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 14.2:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 12:
        if imc >= 23:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 20:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 14.6:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 13:
        if imc >= 24.2:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 21:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 15:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 14:
        if imc >= 25.3:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 21.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 15.6:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 15:
        if imc >= 26.4:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 22.8:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 16.2:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 16:
        if imc >= 27.3:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 23.7:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 16.7:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 17:
        if imc >= 28:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 24.5:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 17.2:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 18:
        if imc >= 28.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 25:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 17.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade >= 19:
        if imc >= 30:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 25:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 18.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

if sexo == "F":
    if idade == 1:
        if imc >= 19.4:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.9:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 2:
        if imc >= 18.5:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.2:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 3:
        if imc >= 18.2:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 16.8:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.2:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 4:
        if imc >= 18.3:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 16.8:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 5:
        if imc >= 18.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 12.8:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 6:
        if imc >= 18.9:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.1:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 12.8:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 7:
        if imc >= 19.5:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.4:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 12.9:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 8:
        if imc >= 20.1:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 17.8:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 9:
        if imc >= 21:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 18.5:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.3:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 10:
        if imc >= 22:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 19.1:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 13.6:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 11:
        if imc >= 23.2:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 20:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 14:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 12:
        if imc >= 24.4:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 20.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 14.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 13:
        if imc >= 25.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 22:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 15.1:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 14:
        if imc >= 26.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 22.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 15.6:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 15:
        if imc >= 27.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 23.6:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 16.1:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 16:
        if imc >= 28.3:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 24.3:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 16.4:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 17:
        if imc >= 28.6:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 24.6:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 16.6:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade == 18:
        if imc >= 28.9:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 24.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 16.7:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))

    if idade >= 19:
        if imc >= 30:
            print("O seu IMC é {:.2f} e você tem obsidade I".format(imc))
        elif imc >= 24.9:
            print("O seu IMC é {:.2f} e você tem pré obsidade".format(imc))
        elif imc >= 18.5:
            print("O seu IMC é {:.2f} e você tem peso normal".format(imc))
        else:
            print("O seu IMC é {:.2f} e você tem magreza".format(imc))
